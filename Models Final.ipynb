# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV, cross_validate
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# %% [markdown]
# Loading data, performing defensive data merge and feature extraction

# %%
data = pd.read_csv('~/data/kobe/data.csv')
data = data[data.shot_made_flag.notnull()].reset_index()
data['opponent'] = data.apply(lambda row: 'NOH' if row['season'] == '2004-05' and row['opponent'] == 'NOP' else row['opponent'], axis=1)
defense = pd.read_pickle('./defense_scrape/defense.pkl')
data = data.merge(defense, left_on=['opponent', 'season'], right_on=['Team_Abb', 'Season'], how='left')
features = ['period', 'playoffs', 'seconds_remaining', 'minutes_remaining', 'season',
            'shot_distance', 'shot_made_flag', 'shot_zone_area', 'game_date', 'matchup', 
            'action_type', 'Def_Rtg']

dataset = data[features]
dataset['total_seconds_remaining'] = 60*dataset['minutes_remaining'] + dataset['seconds_remaining']
dataset.drop('minutes_remaining', axis=1, inplace=True)
dataset.drop('seconds_remaining', axis=1, inplace=True)
dataset['month'] = dataset['game_date'].map(lambda x: x.split('-')[1])
dataset.drop('game_date', axis=1, inplace=True)
dataset['home'] = dataset['matchup'].str.contains('vs').astype('int')
dataset.drop('matchup', axis=1, inplace=True)
dataset["action_type"] = dataset["action_type"].astype('category')
dataset["period"] = dataset["period"].astype('category')
dataset["playoffs"] = dataset["playoffs"].astype('category')
dataset["season"] = dataset["season"].astype('category')
dataset["shot_made_flag"] = dataset["shot_made_flag"].astype('category')
dataset["month"] = dataset["month"].astype('category')
dataset["home"] = dataset["home"].astype('category')
multi_categorical_features = ['action_type', 'period', 'season', 'month', 'shot_zone_area']
numerical_features = ['total_seconds_remaining', 'shot_distance']
for c in multi_categorical_features:
    dummies = pd.get_dummies(dataset[c], drop_first=True)
    dummies = dummies.add_prefix("{}#".format(c))
    dataset.drop(c, axis=1, inplace=True)
    dataset = dataset.join(dummies)

# %% [markdown]
# Define train and test split based on chronological order to avoid leakage (as per Kaggle competition rules)

# %%
n = len(data)
split = 0.8
train = dataset.iloc[:int(split*n),:]
test = dataset.iloc[int(split*n):,:]
X_train = train.drop('shot_made_flag', axis=1)
y_train = train['shot_made_flag']
X_test = test.drop('shot_made_flag', axis=1)
y_test = test['shot_made_flag']

# %% [markdown]
# Define helper function

# %%
def featureImportance(model):
    feature_importance = list(zip(list(dataset),model.feature_importances_))
    feature_importance.sort(key=lambda x: x[1], reverse=True)
    for f in feature_importance:
        print(f'{f[0]}: {f[1]}')

# %% [markdown]
# ## Model 1: Logistic Regression

# %% [markdown]
# First, trying to model with just `shot_distance` as a predictor

# %%
features = ['shot_distance']
X_train_reduced = X_train['shot_distance']
X_test_reduced = X_test['shot_distance']

# %% [markdown]
# Does ok, 60% accuracy with only one variable!

# %%
seed = 7
scoring = 'accuracy'
acc_test_results, acc_train_results = [], []
lr = LogisticRegression(C=10e4)
kfold = KFold(n_splits=10, random_state=seed)
acc_cv_results = cross_val_score(lr, np.array(X_train_reduced).reshape(-1,1), y_train, cv=kfold, scoring=scoring)

scoring = 'neg_log_loss'
nll_test_results, nll_train_results = [], []
kfold = KFold(n_splits=10, random_state=seed)
nll_cv_results = -cross_val_score(lr, np.array(X_train_reduced).reshape(-1,1), y_train, cv=kfold, scoring=scoring)

# %%
print(f'CV Accuracy: {np.mean(acc_cv_results):.4f} ± {np.std(acc_cv_results):.4f}')
print(f'CV Log Loss: {np.mean(nll_cv_results):.4f} ± {np.std(nll_cv_results):.4f}')
# Out:
# CV Accuracy: 0.5984 ± 0.0143
# CV Log Loss: 0.6674 ± 0.0072

# %% [markdown]
# We can also use this single variable logistic regression model to see at what distance the probability of a successful shot is 50%:

# %%
lr = LogisticRegression(C=10e4)
lr.fit(np.array(X_train_reduced).reshape(-1,1), y_train)
dist = np.linspace(dataset.shot_distance.min(), dataset.shot_distance.max(), 1000)
probs = lr.predict_proba(dist.reshape(-1,1))
thresh = -lr.intercept_/lr.coef_

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(dist, probs[:,1], label='Success', color='blue')
ax.plot(dist, probs[:,0], label='Failure', color='red')
ax.axvline(x=thresh, linestyle='--', color='black', label=f'50% threshold ({float(thresh):.2f}ft)')
ax.set_xlabel('Shot Distance (ft)')
ax.set_ylabel('Probability')
ax.legend()
plt.title('Logistic Regression Shot Success Probability from Shot Distance')
plt.show()

# %% [markdown]
# Now, using the full dataset to fit a logistic regression model. Let's do a grid search first

# %%
lr = LogisticRegression()
grid_params = {'penalty':['l1', 'l2'],
               'C':np.exp(np.linspace(-5, 5, 20))
              }
gs = GridSearchCV(estimator=lr,  
                  param_grid=grid_params,
                  scoring='neg_log_loss',
                  cv=5)
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'penalty': ['l1', 'l2'], 'C': array([6.73795e-03, 1.14052e-02, 1.93054e-02, 3.26780e-02, 5.53136e-02,
#        9.36284e-02, 1.58483e-01, 2.68262e-01, 4.54084e-01, 7.68621e-01,
#        1.30103e+00, 2.20224e+00, 3.72769e+00, 6.30981e+00, 1.06805e+01,
#        1.80787e+01, 3.06016e+01, 5.17989e+01, 8.76792e+01, 1.48413e+02])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_log_loss', verbose=0)

# %%
gs.best_params_
# Out:
# {'C': 0.011405219123170522, 'penalty': 'l1'}

# %%
seed = 7
scoring = 'accuracy'
# lr = LogisticRegression(C=0.5, penalty='l1')
lr = gs.best_estimator_
kfold = KFold(n_splits=10, random_state=seed)
acc_CV_results = cross_val_score(lr, X_train, y_train, cv=kfold, scoring=scoring)

scoring = 'neg_log_loss'
nll_CV_results = -cross_val_score(lr, X_train, y_train, cv=kfold, scoring=scoring)

# %%
print(f'CV Accuracy: {np.mean(acc_CV_results):.4f} ± {np.std(acc_CV_results):.4f}')
print(f'CV Log Loss: {np.mean(nll_CV_results):.4f} ± {np.std(nll_CV_results):.4f}')
# Out:
# CV Accuracy: 0.6795 ± 0.0142
# CV Log Loss: 0.6271 ± 0.0087

# %% [markdown]
# ## Model 2: Random Forest

# %% [markdown]
# Start off with a grid search to get the optimal parameters.

# %%
rf = RandomForestClassifier(criterion='gini', n_estimators=200, n_jobs=-1)
kfold = KFold(n_splits=10)
grid_params = {
               'min_samples_leaf':np.arange(1,20,5),
               'max_depth':np.arange(5,20,3)
              }
gs = GridSearchCV(estimator=rf,  
                  param_grid=grid_params,
                  scoring='neg_log_loss',
                  cv=kfold)
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'min_samples_leaf': array([ 1,  6, 11, 16]), 'max_depth': array([ 5,  8, 11, 14, 17])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_log_loss', verbose=0)

# %%
gs.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=17, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=6, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
seed = 7
scoring = 'accuracy'
rf = RandomForestClassifier(criterion='gini', max_depth=17, min_samples_leaf=6, n_estimators=200)
kfold = KFold(n_splits=10, random_state=seed)
acc_CV_results = cross_val_score(rf, X_train, y_train, cv=kfold, scoring=scoring)

scoring = 'neg_log_loss'
nll_CV_results = -cross_val_score(rf, X_train, y_train, cv=kfold, scoring=scoring)

# %%
print(f'CV Accuracy: {np.mean(acc_CV_results):.4f} ± {np.std(acc_CV_results):.4f}')
print(f'CV Log Loss: {np.mean(nll_CV_results):.4f} ± {np.std(nll_CV_results):.4f}')
# Out:
# CV Accuracy: 0.6796 ± 0.0146
# CV Log Loss: 0.6116 ± 0.0105

# %% [markdown]
# We can visualize the effect of regularization on the random forest model:

# %%
seed = 7
scoring = 'accuracy'
error_CV = []
for i in range(1,31,1):
    rf = RandomForestClassifier(n_estimators=100, max_depth=i, n_jobs=-1)
    kfold = KFold(n_splits=10, random_state=seed)
    error_CV.append(1-cross_val_score(rf, X_train, y_train, cv=kfold, scoring=scoring))

# %%
error_CV_mean = [np.mean(e) for e in error_CV]
error_CV_sd = [np.std(e) for e in error_CV]
fig, ax = plt.subplots(figsize=(8,10))
ax.plot(range(1,31), error_CV_mean, color='blue', label='Error Rate')
ax.fill_between(range(1,31), 
                [(a-b) for a,b in zip(error_train_mean, error_train_sd)], 
                [(a+b) for a,b in zip(error_train_mean, error_train_sd)],
                alpha=0.2, color='blue', label='Error Rate ± 1 s.d.')
ax.set_ylabel('CV Error Rate')
ax.set_xlabel('Maximum Depth')
ax.legend()
plt.show()

# %% [markdown]
# The random forest also allows us to check which features are important in this model:

# %%
rf = RandomForestClassifier(criterion='gini', n_estimators=200, min_samples_leaf=20, n_jobs=-1)
rf.fit(X_train, y_train)
featureImportance(rf)
# Out:
# action_type#Jump Hook Shot: 0.2845185219613142
# shot_distance: 0.12351911953248812
# action_type#Jump Shot: 0.08169075743556252
# Def_Rtg: 0.061738998512537495
# action_type#Driving Jump shot: 0.053172894221111766
# shot_made_flag: 0.042296950704625476
# month#12: 0.041562801959959705
# action_type#Running Tip Shot: 0.03615211136198488
# action_type#Running Hook Shot: 0.033215587749907446
# action_type#Driving Bank shot: 0.02657749020737113
# action_type#Pullup Bank shot: 0.015708373871793337
# action_type#Hook Shot: 0.015569899268819258
# total_seconds_remaining: 0.01428228557744076
# action_type#Fadeaway Bank shot: 0.011439361131967947
# action_type#Turnaround Hook Shot: 0.01133417053541418
# action_type#Tip Layup Shot: 0.007316860155542904
# period#3: 0.007128659168995406
# shot_zone_area#Left Side(L): 0.006684430385194566
# action_type#Driving Slam Dunk Shot: 0.006441464471715492
# season#2014-15: 0.006421343594100193
# period#2: 0.006264872453407321
# shot_zone_area#Center(C): 0.005938023086805844
# month#02: 0.004879969717899856
# season#2015-16: 0.004753724550352282
# month#11: 0.004636877675658973
# month#10: 0.004468104293706157
# action_type#Turnaround Jump Shot: 0.004264831963245578
# action_type#Turnaround Bank shot: 0.004129687664911625
# shot_zone_area#Right Side Center(RC): 0.0038629543918617553
# season#2010-11: 0.0037979288856285153
# shot_zone_area#Left Side Center(LC): 0.003735606195952736
# season#2004-05: 0.003728070792419668
# action_type#Reverse Dunk Shot: 0.0036622172598812456
# season#2009-10: 0.0033664429135847346
# month#03: 0.0032861985472784133
# season#1999-00: 0.0032110893467202513
# season#2008-09: 0.003181996492749177
# action_type#Putback Slam Dunk Shot: 0.003176141680379465
# season#2011-12: 0.0030495516325939704
# season#2001-02: 0.0028188808480920325
# period#7: 0.0027086651078802996
# season#2005-06: 0.0026929413697506684
# action_type#Driving Reverse Layup Shot: 0.002628945133887009
# season#2007-08: 0.00262722482081755
# season#2000-01: 0.0025508769056337105
# season#2006-07: 0.0025158924888385877
# season#2003-04: 0.002154761925504463
# action_type#Driving Dunk Shot: 0.00214677323428694
# action_type#Driving Finger Roll Layup Shot: 0.002031683274103464
# season#2013-14: 0.0019996170531886453
# season#2002-03: 0.0015514011485354712
# action_type#Driving Layup Shot: 0.0013632292325484684
# action_type#Finger Roll Shot: 0.0013156310211391575
# action_type#Tip Shot: 0.0009911207656131994
# home: 0.0008017788542429885
# action_type#Hook Bank Shot: 0.0008009520355238137
# action_type#Slam Dunk Shot: 0.0006295793726110899
# season#1997-98: 0.0004824861009297076
# month#06: 0.00039566317267082234
# action_type#Running Jump Shot: 0.000249490866772049
# period#4: 0.00023889397202771248
# action_type#Reverse Slam Dunk Shot: 9.23370752865479e-05
# season#2012-13: 2.6346827403389613e-05
# action_type#Running Finger Roll Shot: 1.845603982789685e-05
# playoffs: 0.0
# action_type#Alley Oop Layup shot: 0.0
# action_type#Cutting Layup Shot: 0.0
# action_type#Driving Finger Roll Shot: 0.0
# action_type#Driving Floating Bank Jump Shot: 0.0
# action_type#Driving Floating Jump Shot: 0.0
# action_type#Driving Hook Shot: 0.0
# action_type#Dunk Shot: 0.0
# action_type#Fadeaway Jump Shot: 0.0
# action_type#Finger Roll Layup Shot: 0.0
# action_type#Floating Jump shot: 0.0
# action_type#Follow Up Dunk Shot: 0.0
# action_type#Jump Bank Shot: 0.0
# action_type#Layup Shot: 0.0
# action_type#Pullup Jump shot: 0.0
# action_type#Putback Dunk Shot: 0.0
# action_type#Putback Layup Shot: 0.0
# action_type#Reverse Layup Shot: 0.0
# action_type#Running Bank shot: 0.0
# action_type#Running Dunk Shot: 0.0
# action_type#Running Finger Roll Layup Shot: 0.0
# action_type#Running Layup Shot: 0.0
# action_type#Running Pull-Up Jump Shot: 0.0
# action_type#Running Reverse Layup Shot: 0.0
# action_type#Running Slam Dunk Shot: 0.0
# action_type#Step Back Jump shot: 0.0
# action_type#Turnaround Fadeaway shot: 0.0
# action_type#Turnaround Finger Roll Shot: 0.0
# period#5: 0.0
# period#6: 0.0
# season#1998-99: 0.0
# month#04: 0.0
# month#05: 0.0

# %% [markdown]
# We can visualize what a typical random forest tree might look like using a decision tree

# %%
dt = DecisionTreeClassifier(max_leaf_nodes=7, criterion='gini')
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=7, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus

# %%
export_graphviz(dt,
                out_file="tree.dot",
                feature_names=list(X_train),
                class_names=['Shot Unsuccessful', 'Shot Successful'],
                rounded=True,
                filled=True
)
# !dot -Tpng tree.dot -o tree.png
Image(filename='tree.png')

# %% [markdown]
# ## Model 3: Gradient Boosted Trees

# %%
gb = GradientBoostingClassifier(n_estimators=120, max_depth=4, min_samples_split=4)
grid_params = {'min_samples_split':range(1,11,1),
               'max_depth':range(1,11,1)}
gs = GridSearchCV(estimator=gb,  
                  param_grid=grid_params,
                  scoring='neg_log_loss',
                  cv=5)
gs.fit(X_train, y_train)

# %%
gs.best_estimator_

# %% [markdown]
# ## Comparing Multiple Models

# %% [markdown]
# Having investigated multiple models, we can now compare their performance through cross-validation on the training set.

# %%
models = [('LR',LogisticRegression(C=0.0114,penalty='l1')), 
          ('RF', RandomForestClassifier(n_estimators=200, criterion='gini', min_samples_leaf=6, max_depth=18)),
          ('DT', DecisionTreeClassifier(max_leaf_nodes=10, criterion='gini')),
          ('KNN', KNeighborsClassifier(n_neighbors=100, p=1)),
          ('GB', GradientBoostingClassifier(n_estimators=120, max_depth=4, min_samples_split=4))]

# %%
seed = 7 # set seed so that all models are tested on the same CV folds 
scoring = 'neg_log_loss'
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = -cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print(f'{name}: {cv_results.mean():.4f} ± {cv_results.std():.4f}')
# Out:
# LR: 0.6271 ± 0.0087
# RF: 0.6107 ± 0.0109
# DT: 0.6137 ± 0.0129
# KNN: 0.6614 ± 0.0078
# GB: 0.6079 ± 0.0124

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.boxplot(results)
ax.set_xticklabels(names)
ax.set_ylabel('Log-Loss')
plt.title('Performance of different ML models')
plt.show()

# %% [markdown]
# It can be seen that the Logistic regression model with penalization performs reasonably well and has low variance which would be expected as the penalization reduces variance at the cost of increased bias. The Random Forest and Decision Tree models perform reasonably similarly, but the Random Forest model has a lower log-loss and lower variance, which is expected as this is an ensemble method which reduces variance and bias. The KNN approach performs poorly. The Gradient Boosted Tree model performs the best of them all in terms of log-loss, but still has fairly high variance.

# %% [markdown]
# Below, we finally evaluate the performance of the GB model on the held out test dataset. A log-loss of 0.6064 and accuracy of 67.7% is achieved, which is in line with our cross-validation estimates from the training set.

# %%
gb = GradientBoostingClassifier(n_estimators=120, max_depth=4, min_samples_split=4)

# %%
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=4,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=4,
#               min_weight_fraction_leaf=0.0, n_estimators=120,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
print(f'Test Accuracy: {gb.score(X_test, y_test):.4f}')
print(f'Test Log-Loss: {log_loss(y_test, gb.predict_proba(X_test)):.4f}')
# Out:
# Test Accuracy: 0.6770
# Test Log-Loss: 0.6064

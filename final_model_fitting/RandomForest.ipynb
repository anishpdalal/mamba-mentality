# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV, cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from dtreeviz.trees import *
from sklearn.ensemble import GradientBoostingClassifier

# %%
#data = pd.read_csv('~/data/kobe/data.csv')
data = pd.read_csv('~/desktop/finalproject/data.csv')
data = data[data.shot_made_flag.notnull()].reset_index()

# %%
data['opponent'] = data.apply(lambda row: 'NOH' if row['season'] == '2004-05' and row['opponent'] == 'NOP' else row['opponent'], axis=1)

# %%
defense = pd.read_pickle('./defense_scrape/defense.pkl')
data = data.merge(defense, left_on=['opponent', 'season'], right_on=['Team_Abb', 'Season'], how='left')

# %%
def evaluateModel(model):
    print(f'Test Accuracy: {model.score(X_test, y_test):.4f}')
    print(f'Test Log-Loss: {log_loss(y_test, model.predict_proba(X_test)):.4f}')
    print(f'Training Accuracy: {model.score(X_train, y_train):.4f}')

# %%
def featureImportance(model):
    feature_importance = list(zip(list(X),model.feature_importances_))
    feature_importance.sort(key=lambda x: x[1], reverse=True)
    for f in feature_importance:
        print(f'{f[0]}: {f[1]}')

# %% [markdown]
# # Model 1: Random Forest

# %%
features = ['period', 'playoffs', 'seconds_remaining', 'minutes_remaining', 'season',
            'shot_distance', 'shot_made_flag', 'shot_zone_area', 'game_date', 'matchup', 
            'action_type', 'Def_Rtg']

dataset = data[features]
dataset['total_seconds_remaining'] = 60*dataset['minutes_remaining'] + dataset['seconds_remaining']
dataset.drop('minutes_remaining', axis=1, inplace=True)
dataset.drop('seconds_remaining', axis=1, inplace=True)
dataset['month'] = dataset['game_date'].map(lambda x: x.split('-')[1])
dataset.drop('game_date', axis=1, inplace=True)
dataset['home'] = dataset['matchup'].str.contains('vs').astype('int')
dataset.drop('matchup', axis=1, inplace=True)
dataset["action_type"] = dataset["action_type"].astype('category')
dataset["period"] = dataset["period"].astype('category')
dataset["playoffs"] = dataset["playoffs"].astype('category')
dataset["season"] = dataset["season"].astype('category')
dataset["shot_made_flag"] = dataset["shot_made_flag"].astype('category')
dataset["month"] = dataset["month"].astype('category')
dataset["home"] = dataset["home"].astype('category')
multi_categorical_features = ['action_type', 'period', 'season', 'month', 'shot_zone_area']
numerical_features = ['total_seconds_remaining', 'shot_distance']
for c in multi_categorical_features:
    dummies = pd.get_dummies(dataset[c], drop_first=True)
    dummies = dummies.add_prefix("{}#".format(c))
    dataset.drop(c, axis=1, inplace=True)
    dataset = dataset.join(dummies)

X = dataset.loc[:, dataset.columns != 'shot_made_flag']
y = dataset['shot_made_flag']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
rf = RandomForestClassifier(n_estimators=200)
grid_params = {'criterion':['entropy'],
               'min_samples_leaf':np.arange(1,20,2)
              }
gs = GridSearchCV(estimator=rf,  
                  param_grid=grid_params,
                  scoring='neg_log_loss',
                  cv=5)
gs.fit(X_train, y_train)
evaluateModel(gs)
print(f"{gs.best_estimator_}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e35c8b5a2708> in <module>
#       7                   scoring='neg_log_loss',
#       8                   cv=5)
# ----> 9 gs.fit(X_train, y_train)
#      10 evaluateModel(gs)
#      11 print(f"{gs.best_estimator_}")
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
#     724         results = results_container[0]
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1189     def _run_search(self, evaluate_candidates):
#    1190         """Search all candidates in param_grid"""
# -> 1191         evaluate_candidates(ParameterGrid(self.param_grid))
#    1192
#    1193
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     709                                for parameters, (train, test)
#     710                                in product(candidate_params,
# --> 711                                           cv.split(X, y, groups)))
#     712
#     713                 all_candidate_params.extend(candidate_params)
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     333                     t, self, X, y, sample_weight, i, len(trees),
#     334                     verbose=self.verbose, class_weight=self.class_weight)
# --> 335                 for i, t in enumerate(trees))
#     336
#     337             # Collect newly grown trees
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     984                 self._iterating = self._original_iterator is not None
#     985
# --> 986             while self.dispatch_one_batch(iterator):
#     987                 pass
#     988
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     823                 return False
#     824             else:
# --> 825                 self._dispatch(tasks)
#     826                 return True
#     827
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     780         with self._lock:
#     781             job_idx = len(self._jobs)
# --> 782             job = self._backend.apply_async(batch, callback=cb)
#     783             # A job can complete so quickly than its callback is
#     784             # called before we get here, causing self._jobs to
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     543         # Don't delay the application, to avoid keeping the input
#     544         # arguments in memory
# --> 545         self.results = batch()
#     546
#     547     def get(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     259         with parallel_backend(self._backend):
#     260             return [func(*args, **kwargs)
# --> 261                     for func, args, kwargs in self.items]
#     262
#     263     def __len__(self):
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     797             sample_weight=sample_weight,
#     798             check_input=check_input,
# --> 799             X_idx_sorted=X_idx_sorted)
#     800         return self
#     801
#
# /anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     363                                            min_impurity_split)
#     364
# --> 365         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     366
#     367         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
gs.best_estimator_timator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf = RandomForestClassifier(n_estimators=200, criterion='entropy', min_samples_leaf=5, n_jobs=-1)
rf.fit(X_train, y_train)
evaluateModel(rf)
# Out:
# Test Accuracy: 0.6868
# Test Log-Loss: 0.6038
# Training Accuracy: 0.7115

# %%
featureImportance(rf)
# Out:
# action_type#Jump Shot: 0.15763979228482464
# total_seconds_remaining: 0.1252699463678601
# shot_distance: 0.11835617926550474
# Def_Rtg: 0.09628189438979101
# action_type#Layup Shot: 0.04528510501102002
# action_type#Slam Dunk Shot: 0.031348561779122895
# action_type#Driving Layup Shot: 0.029567223375038837
# home: 0.025264398225596743
# action_type#Driving Dunk Shot: 0.02156978167235983
# shot_zone_area#Center(C): 0.02150312113703447
# action_type#Running Jump Shot: 0.020264865358148993
# period#3: 0.014777433335774375
# period#4: 0.012979604099524844
# period#2: 0.01227469082076166
# month#03: 0.010668524394727052
# month#12: 0.010480477937415437
# month#11: 0.009880789817749218
# month#02: 0.009734163691169162
# action_type#Jump Bank Shot: 0.009516035652796075
# month#04: 0.009030753571406959
# action_type#Pullup Jump shot: 0.008338100650411769
# action_type#Turnaround Jump Shot: 0.007662367505697507
# shot_zone_area#Right Side(R): 0.007555060283095767
# playoffs: 0.007473838942173687
# shot_zone_area#Right Side Center(RC): 0.0073527621380681755
# season#2008-09: 0.007330976101818688
# shot_zone_area#Left Side(L): 0.007156628505357468
# shot_zone_area#Left Side Center(LC): 0.006963746125079928
# season#2005-06: 0.006662848494363692
# season#2009-10: 0.006654250677776651
# season#2000-01: 0.0064722307145082154
# season#2015-16: 0.006443677979447219
# season#2002-03: 0.006373837073892747
# season#2011-12: 0.006352506881447696
# action_type#Fadeaway Jump Shot: 0.006207775232257173
# season#2007-08: 0.006098488400089846
# season#2006-07: 0.005821296364501741
# season#2010-11: 0.005817348801677653
# season#2001-02: 0.0057143829843124
# season#1999-00: 0.005431286797048067
# month#05: 0.005222322465732786
# season#2012-13: 0.005150635595980049
# action_type#Dunk Shot: 0.00499654546998631
# action_type#Tip Shot: 0.004839413248475693
# season#2004-05: 0.0045061701002930684
# season#2003-04: 0.004495148631465165
# season#1997-98: 0.004381021444888372
# season#2014-15: 0.0037574411540921256
# season#1998-99: 0.003409200567941283
# action_type#Reverse Dunk Shot: 0.003036787225324799
# action_type#Driving Slam Dunk Shot: 0.002901117159711102
# month#06: 0.0027064259526013625
# action_type#Turnaround Fadeaway shot: 0.002597219990848131
# action_type#Reverse Layup Shot: 0.002583535168387522
# action_type#Driving Finger Roll Layup Shot: 0.001922908402015211
# action_type#Driving Finger Roll Shot: 0.0018547328356958365
# action_type#Running Hook Shot: 0.001774654014677284
# action_type#Running Bank shot: 0.001537050599644854
# period#5: 0.0014390529657714749
# action_type#Hook Shot: 0.001347535036745198
# month#10: 0.0013194529347893766
# action_type#Turnaround Bank shot: 0.0012266935250620581
# action_type#Step Back Jump shot: 0.0010959711981821866
# action_type#Driving Reverse Layup Shot: 0.0010321835537791103
# action_type#Fadeaway Bank shot: 0.0009604673451298093
# action_type#Floating Jump shot: 0.0009314236486259596
# action_type#Reverse Slam Dunk Shot: 0.0006800332738951312
# action_type#Running Dunk Shot: 0.0005563179757284318
# action_type#Alley Oop Layup shot: 0.0004597191290934074
# action_type#Running Layup Shot: 0.00040814693619023115
# action_type#Jump Hook Shot: 0.00030334387337106473
# action_type#Finger Roll Layup Shot: 0.0002498044436836042
# action_type#Finger Roll Shot: 0.00022141077135715784
# action_type#Driving Jump shot: 0.00020292133675244264
# season#2013-14: 0.00018350256281724406
# period#6: 3.98218743250807e-05
# action_type#Driving Hook Shot: 3.914774860304651e-05
# action_type#Hook Bank Shot: 3.352004135598129e-05
# action_type#Follow Up Dunk Shot: 2.044695632790272e-05
# action_type#Cutting Layup Shot: 0.0
# action_type#Driving Bank shot: 0.0
# action_type#Driving Floating Bank Jump Shot: 0.0
# action_type#Driving Floating Jump Shot: 0.0
# action_type#Pullup Bank shot: 0.0
# action_type#Putback Dunk Shot: 0.0
# action_type#Putback Layup Shot: 0.0
# action_type#Putback Slam Dunk Shot: 0.0
# action_type#Running Finger Roll Layup Shot: 0.0
# action_type#Running Finger Roll Shot: 0.0
# action_type#Running Pull-Up Jump Shot: 0.0
# action_type#Running Reverse Layup Shot: 0.0
# action_type#Running Slam Dunk Shot: 0.0
# action_type#Running Tip Shot: 0.0
# action_type#Tip Layup Shot: 0.0
# action_type#Turnaround Finger Roll Shot: 0.0
# action_type#Turnaround Hook Shot: 0.0
# period#7: 0.0

# %% [markdown]
# # Model 2: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
features = ['shot_distance', 'shot_made_flag']
X = dataset.loc[:, dataset.columns != 'shot_made_flag']
y = dataset['shot_made_flag']
X_train, X_test, y_train, y_test = train_test_split(X, y)
dataset = data[features]

# %%
lr = LogisticRegression(C=10e4)
lr.fit(X_train, y_train)
evaluateModel(lr)
# Out:
# Test Accuracy: 0.6118
# Test Log-Loss: 0.6620
# Training Accuracy: 0.5928

# %%
dist = np.linspace(dataset.shot_distance.min(), dataset.shot_distance.max(), 1000)
probs = lr.predict_proba(X=dist.reshape(-1,1))

# %%
thresh = -lr.intercept_/lr.coef_

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(dist, probs[:,1], label='Success', color='blue')
ax.plot(dist, probs[:,0], label='Failure', color='red')
ax.axvline(x=thresh, linestyle='--', color='black', label=f'50% threshold ({float(thresh):.2f}ft)')
ax.set_xlabel('Shot Distance (ft)')
ax.set_ylabel('Probability')
ax.legend()
plt.title('Logistic Regression Shot Success Probability from Shot Distance')
plt.show()

# %% [markdown]
# ## Logistic Regression with the full dataset

# %%
features = ['period', 'playoffs', 'seconds_remaining', 'minutes_remaining', 'season',
            'shot_distance', 'shot_made_flag', 'shot_zone_area', 'game_date', 'matchup', 
            'action_type', 'Def_Rtg']

dataset = data[features]
dataset['total_seconds_remaining'] = 60*dataset['minutes_remaining'] + dataset['seconds_remaining']
dataset.drop('minutes_remaining', axis=1, inplace=True)
dataset.drop('seconds_remaining', axis=1, inplace=True)
dataset['month'] = dataset['game_date'].map(lambda x: x.split('-')[1])
dataset.drop('game_date', axis=1, inplace=True)
dataset['home'] = dataset['matchup'].str.contains('vs').astype('int')
dataset.drop('matchup', axis=1, inplace=True)
dataset["action_type"] = dataset["action_type"].astype('category')
dataset["period"] = dataset["period"].astype('category')
dataset["playoffs"] = dataset["playoffs"].astype('category')
dataset["season"] = dataset["season"].astype('category')
dataset["shot_made_flag"] = dataset["shot_made_flag"].astype('category')
dataset["month"] = dataset["month"].astype('category')
dataset["home"] = dataset["home"].astype('category')
multi_categorical_features = ['action_type', 'period', 'season', 'month', 'shot_zone_area']
numerical_features = ['total_seconds_remaining', 'shot_distance']
for c in multi_categorical_features:
    dummies = pd.get_dummies(dataset[c], drop_first=True)
    dummies = dummies.add_prefix("{}#".format(c))
    dataset.drop(c, axis=1, inplace=True)
    dataset = dataset.join(dummies)

X = dataset.loc[:, dataset.columns != 'shot_made_flag']
y = dataset['shot_made_flag']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
lr = LogisticRegression(C=10e4)
lr.fit(X_train, y_train)
evaluateModel(lr)
# Out:
# Test Accuracy: 0.6819
# Test Log-Loss: 0.6109
# Training Accuracy: 0.6832

# %%
lr = LogisticRegression(C=0.5,penalty='l1')
lr.fit(X_train, y_train)
evaluateModel(lr)
# Out:
# Test Accuracy: 0.6822
# Test Log-Loss: 0.6103
# Training Accuracy: 0.6824

# %% [markdown]
# ## Model 3: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_leaf_nodes=10, criterion='entropy')

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=10,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
evaluateModel(dt)
# Out:
# Test Accuracy: 0.6789
# Test Log-Loss: 0.6119
# Training Accuracy: 0.6803

# %%
viz = dtreeviz(dt, 
               X_train, 
               y_train,
               target_name='shot_made_flag',
               feature_names=list(X_train), 
               class_names={0.0:'shot_made',1.0:'shot_not_made'}  # need class_names for classifier
              )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-4c37f48f362e> in <module>()
#       4                target_name='shot_made_flag',
#       5                feature_names=list(X_train),
# ----> 6                class_names={0.0:'shot_made',1.0:'shot_not_made'}  # need class_names for classifier
#       7               )
#
# /anaconda3/lib/python3.6/site-packages/dtreeviz/trees.py in dtreeviz(tree_model, X_train, y_train, feature_names, target_name, class_names, precision, orientation, show_root_edge_labels, show_node_labels, fancy, histtype, highlight_path, X, max_X_features_LR, max_X_features_TD)
#     701     if shadow_tree.isclassifier():
#     702         nbins = get_num_bins(histtype, n_classes)
# --> 703         node_heights = shadow_tree.get_split_node_heights(X_train, y_train, nbins=nbins)
#     704
#     705     internal = []
#
# /anaconda3/lib/python3.6/site-packages/dtreeviz/shadow.py in get_split_node_heights(self, X_train, y_train, nbins)
#     129             height_of_bins = np.zeros(nbins)
#     130             for cl in class_values:
# --> 131                 hist, foo = np.histogram(X_hist[cl], bins=bins, range=overall_feature_range)
#     132                 # print(f"class {cl}: goal_n={len(bins):2d} n={len(hist):2d} {hist}")
#     133                 height_of_bins += hist
#
# TypeError: list indices must be integers or slices, not numpy.float64

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus

# %%
from sklearn.tree import export_graphviz
    
export_graphviz(dt,
                out_file="tree.dot",
                feature_names=list(X_train),
                class_names=['Shot Unsuccessful', 'Shot Successful'],
                rounded=True,
                filled=True
)

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
Image(filename='tree.png')

# %%
featureImportance(dt)
# Out:
# action_type#Jump Shot: 0.6166864543026478
# action_type#Layup Shot: 0.19754316077201362
# action_type#Slam Dunk Shot: 0.04375941662539692
# shot_distance: 0.04293182378933021
# action_type#Driving Dunk Shot: 0.03245614484381102
# total_seconds_remaining: 0.028921961820463426
# home: 0.021027835652824112
# action_type#Tip Shot: 0.01667320219351286
# playoffs: 0.0
# Def_Rtg: 0.0
# action_type#Alley Oop Layup shot: 0.0
# action_type#Cutting Layup Shot: 0.0
# action_type#Driving Bank shot: 0.0
# action_type#Driving Finger Roll Layup Shot: 0.0
# action_type#Driving Finger Roll Shot: 0.0
# action_type#Driving Floating Bank Jump Shot: 0.0
# action_type#Driving Floating Jump Shot: 0.0
# action_type#Driving Hook Shot: 0.0
# action_type#Driving Jump shot: 0.0
# action_type#Driving Layup Shot: 0.0
# action_type#Driving Reverse Layup Shot: 0.0
# action_type#Driving Slam Dunk Shot: 0.0
# action_type#Dunk Shot: 0.0
# action_type#Fadeaway Bank shot: 0.0
# action_type#Fadeaway Jump Shot: 0.0
# action_type#Finger Roll Layup Shot: 0.0
# action_type#Finger Roll Shot: 0.0
# action_type#Floating Jump shot: 0.0
# action_type#Follow Up Dunk Shot: 0.0
# action_type#Hook Bank Shot: 0.0
# action_type#Hook Shot: 0.0
# action_type#Jump Bank Shot: 0.0
# action_type#Jump Hook Shot: 0.0
# action_type#Pullup Bank shot: 0.0
# action_type#Pullup Jump shot: 0.0
# action_type#Putback Dunk Shot: 0.0
# action_type#Putback Layup Shot: 0.0
# action_type#Putback Slam Dunk Shot: 0.0
# action_type#Reverse Dunk Shot: 0.0
# action_type#Reverse Layup Shot: 0.0
# action_type#Reverse Slam Dunk Shot: 0.0
# action_type#Running Bank shot: 0.0
# action_type#Running Dunk Shot: 0.0
# action_type#Running Finger Roll Layup Shot: 0.0
# action_type#Running Finger Roll Shot: 0.0
# action_type#Running Hook Shot: 0.0
# action_type#Running Jump Shot: 0.0
# action_type#Running Layup Shot: 0.0
# action_type#Running Pull-Up Jump Shot: 0.0
# action_type#Running Reverse Layup Shot: 0.0
# action_type#Running Slam Dunk Shot: 0.0
# action_type#Running Tip Shot: 0.0
# action_type#Step Back Jump shot: 0.0
# action_type#Tip Layup Shot: 0.0
# action_type#Turnaround Bank shot: 0.0
# action_type#Turnaround Fadeaway shot: 0.0
# action_type#Turnaround Finger Roll Shot: 0.0
# action_type#Turnaround Hook Shot: 0.0
# action_type#Turnaround Jump Shot: 0.0
# period#2: 0.0
# period#3: 0.0
# period#4: 0.0
# period#5: 0.0
# period#6: 0.0
# period#7: 0.0
# season#1997-98: 0.0
# season#1998-99: 0.0
# season#1999-00: 0.0
# season#2000-01: 0.0
# season#2001-02: 0.0
# season#2002-03: 0.0
# season#2003-04: 0.0
# season#2004-05: 0.0
# season#2005-06: 0.0
# season#2006-07: 0.0
# season#2007-08: 0.0
# season#2008-09: 0.0
# season#2009-10: 0.0
# season#2010-11: 0.0
# season#2011-12: 0.0
# season#2012-13: 0.0
# season#2013-14: 0.0
# season#2014-15: 0.0
# season#2015-16: 0.0
# month#02: 0.0
# month#03: 0.0
# month#04: 0.0
# month#05: 0.0
# month#06: 0.0
# month#10: 0.0
# month#11: 0.0
# month#12: 0.0
# shot_zone_area#Center(C): 0.0
# shot_zone_area#Left Side Center(LC): 0.0
# shot_zone_area#Left Side(L): 0.0
# shot_zone_area#Right Side Center(RC): 0.0
# shot_zone_area#Right Side(R): 0.0

# %% [markdown]
# ## Comparing multiple models

# %%
features = ['period', 'playoffs', 'seconds_remaining', 'minutes_remaining', 'season',
            'shot_distance', 'shot_made_flag', 'shot_zone_area', 'game_date', 'matchup', 
            'action_type', 'Def_Rtg']

dataset = data[features]
dataset['total_seconds_remaining'] = 60*dataset['minutes_remaining'] + dataset['seconds_remaining']
dataset.drop('minutes_remaining', axis=1, inplace=True)
dataset.drop('seconds_remaining', axis=1, inplace=True)
dataset['month'] = dataset['game_date'].map(lambda x: x.split('-')[1])
dataset.drop('game_date', axis=1, inplace=True)
dataset['home'] = dataset['matchup'].str.contains('vs').astype('int')
dataset.drop('matchup', axis=1, inplace=True)
dataset["action_type"] = dataset["action_type"].astype('category')
dataset["period"] = dataset["period"].astype('category')
dataset["playoffs"] = dataset["playoffs"].astype('category')
dataset["season"] = dataset["season"].astype('category')
dataset["shot_made_flag"] = dataset["shot_made_flag"].astype('category')
dataset["month"] = dataset["month"].astype('category')
dataset["home"] = dataset["home"].astype('category')
multi_categorical_features = ['action_type', 'period', 'season', 'month', 'shot_zone_area']
numerical_features = ['total_seconds_remaining', 'shot_distance']
for c in multi_categorical_features:
    dummies = pd.get_dummies(dataset[c], drop_first=True)
    dummies = dummies.add_prefix("{}#".format(c))
    dataset.drop(c, axis=1, inplace=True)
    dataset = dataset.join(dummies)

X = dataset.loc[:, dataset.columns != 'shot_made_flag']
y = dataset['shot_made_flag']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
models = [('LR',LogisticRegression(C=0.5,penalty='l1')), 
          ('RF', RandomForestClassifier(n_estimators=200, criterion='entropy', min_samples_leaf=5)),
          ('DT', DecisionTreeClassifier(max_leaf_nodes=10, criterion='entropy')),
          ('KNN', KNeighborsClassifier(n_neighbors=100, p=1)),
         ('GB', GradientBoostingClassifier(n_estimators=120, max_depth=4, min_samples_split=4))]

# %%
seed = 7 # set seed so that all models are tested on the same CV folds 
scoring = 'neg_log_loss'
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = -cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    print(f'{name}: {cv_results.mean():.4f} ± {cv_results.std():.4f}')
# Out:
# LR: 0.6110 ± 0.0085
# RF: 0.6071 ± 0.0067
# DT: 0.6112 ± 0.0080
# KNN: 0.6608 ± 0.0064
# GB: 0.6065 ± 0.0071

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.boxplot(results)
ax.set_xticklabels(names)
ax.set_ylabel('Log-Loss')
plt.title('Performance of different ML models')
plt.show()

# %%
from bs4 import BeautifulSoup
import urllib.request
import time
from selenium import webdriver
import csv
# from urllib.request import Request, urlopen

# %%
url = 'https://stats.nba.com/teams/defense/?sort=DEF_RATING&dir=-1&Season=2001-02&SeasonType=Regular%20Season'

driver = webdriver.Chrome('/usr/local/bin/chromedriver')  # Optional argument, if not specified will search path.
# or, fill in your ANACONDA_INSTALL_DIR and try this:
# driver = webdriver.Chrome('ANACONDA_INSTALL_DIR/chromedriver-Darwin')

driver.get(url)

html = driver.find_element_by_tag_name('html').get_attribute('innerHTML')
driver.quit() # close browser

# %%
f = open()
# Out:
#    https://stats.nba.com/teams/defense/?sort=DEF_RATING&dir=-1&Season=1996-97&SeasonType=Regular%20Season
# 0   https://stats.nba.com/teams/defense/?sort=DEF_...
# 1   https://stats.nba.com/teams/defense/?sort=DEF_...
# 2   https://stats.nba.com/teams/defense/?sort=DEF_...
# 3   https://stats.nba.com/teams/defense/?sort=DEF_...
# 4   https://stats.nba.com/teams/defense/?sort=DEF_...
# 5   https://stats.nba.com/teams/defense/?sort=DEF_...
# 6   https://stats.nba.com/teams/defense/?sort=DEF_...
# 7   https://stats.nba.com/teams/defense/?sort=DEF_...
# 8   https://stats.nba.com/teams/defense/?sort=DEF_...
# 9   https://stats.nba.com/teams/defense/?sort=DEF_...
# 10  https://stats.nba.com/teams/defense/?sort=DEF_...
# 11  https://stats.nba.com/teams/defense/?sort=DEF_...
# 12  https://stats.nba.com/teams/defense/?sort=DEF_...
# 13  https://stats.nba.com/teams/defense/?sort=DEF_...
# 14  https://stats.nba.com/teams/defense/?sort=DEF_...
# 15  https://stats.nba.com/teams/defense/?sort=DEF_...
# 16  https://stats.nba.com/teams/defense/?sort=DEF_...
# 17  https://stats.nba.com/teams/defense/?sort=DEF_...
# 18  https://stats.nba.com/teams/defense/?sort=DEF_...
